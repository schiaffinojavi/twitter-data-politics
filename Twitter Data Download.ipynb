# %%
import tweepy
from collections import defaultdict
import pickle

LABOUR_HASHTAG = '#Labour'
TORY_HASHTAG = '#Tories'

# %%
keys = []
with open('twitter_keys.txt') as f:
    for line in f:
        keys.append(line.rstrip())

consumer_key = keys[0]
consumer_secret = keys[1]

access_token = keys[2]
access_token_secret = keys[3]



auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
def get_api():
    #uncomment to use user auth instead of app auth
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    #auth = tweepy.AppAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    
    return tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, retry_count=5, retry_delay=2*60)

def get_hashtag_tweets(api, hashtags):
    hashtag_tweets = defaultdict(list)
    for hashtag in hashtags:
        for tweet in tweepy.Cursor(api.search, hashtag).items(2000):
            hashtag_tweets[hashtag].append(tweet)
    
        print("Got %i tweets for hashtag %s" % (len(hashtag_tweets[hashtag]), hashtag))
        print('First tweet is', hashtag_tweets[hashtag][0])
    return hashtag_tweets

# %%
api = get_api()

hashtag_tweets = get_hashtag_tweets(api, [LABOUR_HASHTAG, TORY_HASHTAG])
# Out:
# Got 2000 tweets for hashtag #Labour
# First tweet is Status(_api=<tweepy.api.API object at 0x10c0364a8>, _json={'created_at': 'Tue Jul 11 08:44:33 +0000 2017', 'id': 884694889719504896, 'id_str': '884694889719504896', 'text': 'RT @AFD_en: What is the the effect of siblings on #Niger labor market integration ? Read the reseach paper ►https://t.co/VqrHZ9HHXO #Labour…', 'truncated': False, 'entities': {'hashtags': [{'text': 'Niger', 'indices': [50, 56]}, {'text': 'Labour', 'indices': [132, 139]}], 'symbols': [], 'user_mentions': [{'screen_name': 'AFD_en', 'name': 'AFD_en', 'id': 783726610621075456, 'id_str': '783726610621075456', 'indices': [3, 10]}], 'urls': [{'url': 'https://t.co/VqrHZ9HHXO', 'expanded_url': 'http://bit.ly/2ua7NTq', 'display_url': 'bit.ly/2ua7NTq', 'indices': [108, 131]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4209262283, 'id_str': '4209262283', 'name': 'Bénédicte Niel', 'screen_name': 'BenedicteNiel', 'location': '', 'description': "Research Programme Co-Director @CliMates_ ; Master's Student @SciencesPo & ParisVI; writting a research paper on deforestation w/ @IDDRI; ... but also singer !", 'url': 'https://t.co/CiUo8dkhgY', 'entities': {'url': {'urls': [{'url': 'https://t.co/CiUo8dkhgY', 'expanded_url': 'http://www.climates.fr', 'display_url': 'climates.fr', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 233, 'friends_count': 448, 'listed_count': 21, 'created_at': 'Tue Nov 17 11:16:36 +0000 2015', 'favourites_count': 483, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 637, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/771488958748516354/PrIBFY-C_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/771488958748516354/PrIBFY-C_normal.jpg', 'profile_link_color': '990022', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jul 10 15:24:57 +0000 2017', 'id': 884433268095033344, 'id_str': '884433268095033344', 'text': 'What is the the effect of siblings on #Niger labor market integration ? Read the reseach paper ►… https://t.co/uSI0r4wAhB', 'truncated': True, 'entities': {'hashtags': [{'text': 'Niger', 'indices': [38, 44]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/uSI0r4wAhB', 'expanded_url': 'https://twitter.com/i/web/status/884433268095033344', 'display_url': 'twitter.com/i/web/status/8…', 'indices': [98, 121]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 783726610621075456, 'id_str': '783726610621075456', 'name': 'AFD_en', 'screen_name': 'AFD_en', 'location': 'Johannesburg, South Africa', 'description': 'French #Development Agency - Official English version of @AFD_France & directly ...
# Rate limit reached. Sleeping for: 843
# Got 2000 tweets for hashtag #Tories
# First tweet is Status(_api=<tweepy.api.API object at 0x10c0364a8>, _json={'created_at': 'Tue Jul 11 08:44:35 +0000 2017', 'id': 884694899869847555, 'id_str': '884694899869847555', 'text': "RT @Far_Right_Watch: #Tories Theresa May will 'relaunch' her Policies today. Here's how it will go ... https://t.co/5MERlEQw3x", 'truncated': False, 'entities': {'hashtags': [{'text': 'Tories', 'indices': [21, 28]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Far_Right_Watch', 'name': 'Far Right Watch', 'id': 431922490, 'id_str': '431922490', 'indices': [3, 19]}], 'urls': [], 'media': [{'id': 884694043506212864, 'id_str': '884694043506212864', 'indices': [103, 126], 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DEcQi5YXgAAgzEJ.jpg', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DEcQi5YXgAAgzEJ.jpg', 'url': 'https://t.co/5MERlEQw3x', 'display_url': 'pic.twitter.com/5MERlEQw3x', 'expanded_url': 'https://twitter.com/Far_Right_Watch/status/884694122283642880/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 340, 'h': 236, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 360, 'h': 250, 'resize': 'fit'}, 'medium': {'w': 360, 'h': 250, 'resize': 'fit'}}, 'source_status_id': 884694122283642880, 'source_status_id_str': '884694122283642880', 'source_user_id': 431922490, 'source_user_id_str': '431922490'}]}, 'extended_entities': {'media': [{'id': 884694043506212864, 'id_str': '884694043506212864', 'indices': [103, 126], 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DEcQi5YXgAAgzEJ.jpg', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DEcQi5YXgAAgzEJ.jpg', 'url': 'https://t.co/5MERlEQw3x', 'display_url': 'pic.twitter.com/5MERlEQw3x', 'expanded_url': 'https://twitter.com/Far_Right_Watch/status/884694122283642880/photo/1', 'type': 'animated_gif', 'sizes': {'small': {'w': 340, 'h': 236, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 360, 'h': 250, 'resize': 'fit'}, 'medium': {'w': 360, 'h': 250, 'resize': 'fit'}}, 'source_status_id': 884694122283642880, 'source_status_id_str': '884694122283642880', 'source_user_id': 431922490, 'source_user_id_str': '431922490', 'video_info': {'aspect_ratio': [36, 25], 'variants': [{'bitrate': 0, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/tweet_video/DEcQi5YXgAAgzEJ.mp4'}]}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2478694018, 'id_str': '2478694018', 'name': 'BrandedWhistleblower', 'screen_name': 'Nolliag66', 'location': 'walking my Dog ', 'description': '#whistleblower\n\nMy first concern was raised in 1995, then 2006, 2009, 2010, 2012, 2017, the system is broken. #Whistleblowers are demonised & marginalised.', 'url': 'https://t.co/kQYr28EBTr', 'entities': {'url': {'urls': [{'url': 'https://t.co/kQYr28EBTr', 'expanded_url': 'https://nolliag66.wordpress.com', 'display_url': 'nolliag66.wordpress.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2046, 'friends_count': 2692, 'listed_count': 77, 'created_at': 'Sat Apr 12 11:51:33 +0000 2014', 'favourites_count': 12870, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 32845, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/873160622644572160/e0CxVF1Y_normal.jpg', 'profile_image_url_https': 'https://pbs.tw ...

# %%
with open('hashtag_tweets', 'wb') as f:
    pickle.dump(hashtag_tweets, f)

# %%
with open('hashtag_tweets', 'rb') as f:
    tweets = pickle.load(f)
    
tweets['#Labour'][0]
# Out:
# Status(_json={'created_at': 'Tue Jul 11 08:44:33 +0000 2017', 'id': 884694889719504896, 'id_str': '884694889719504896', 'text': 'RT @AFD_en: What is the the effect of siblings on #Niger labor market integration ? Read the reseach paper ►https://t.co/VqrHZ9HHXO #Labour…', 'truncated': False, 'entities': {'hashtags': [{'text': 'Niger', 'indices': [50, 56]}, {'text': 'Labour', 'indices': [132, 139]}], 'symbols': [], 'user_mentions': [{'screen_name': 'AFD_en', 'name': 'AFD_en', 'id': 783726610621075456, 'id_str': '783726610621075456', 'indices': [3, 10]}], 'urls': [{'url': 'https://t.co/VqrHZ9HHXO', 'expanded_url': 'http://bit.ly/2ua7NTq', 'display_url': 'bit.ly/2ua7NTq', 'indices': [108, 131]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4209262283, 'id_str': '4209262283', 'name': 'Bénédicte Niel', 'screen_name': 'BenedicteNiel', 'location': '', 'description': "Research Programme Co-Director @CliMates_ ; Master's Student @SciencesPo & ParisVI; writting a research paper on deforestation w/ @IDDRI; ... but also singer !", 'url': 'https://t.co/CiUo8dkhgY', 'entities': {'url': {'urls': [{'url': 'https://t.co/CiUo8dkhgY', 'expanded_url': 'http://www.climates.fr', 'display_url': 'climates.fr', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 233, 'friends_count': 448, 'listed_count': 21, 'created_at': 'Tue Nov 17 11:16:36 +0000 2015', 'favourites_count': 483, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 637, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/771488958748516354/PrIBFY-C_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/771488958748516354/PrIBFY-C_normal.jpg', 'profile_link_color': '990022', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jul 10 15:24:57 +0000 2017', 'id': 884433268095033344, 'id_str': '884433268095033344', 'text': 'What is the the effect of siblings on #Niger labor market integration ? Read the reseach paper ►… https://t.co/uSI0r4wAhB', 'truncated': True, 'entities': {'hashtags': [{'text': 'Niger', 'indices': [38, 44]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/uSI0r4wAhB', 'expanded_url': 'https://twitter.com/i/web/status/884433268095033344', 'display_url': 'twitter.com/i/web/status/8…', 'indices': [98, 121]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 783726610621075456, 'id_str': '783726610621075456', 'name': 'AFD_en', 'screen_name': 'AFD_en', 'location': 'Johannesburg, South Africa', 'description': 'French #Development Agency - Official English version of @AFD_France & directly managed by our colleagues in Johannesburg #WorldInCommon |  ...
